# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
data = pd.read_csv("C:/Users/maity/OneDrive/Desktop/Pworld/classification/batteries.csv")

# %%
sns.swarmplot(x=data['Crystal System'],
             y=data['E Above Hull (eV)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sns.swarmplot(x=data['Crystal System'],
             y=data['Nsites'])
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 20.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.

# %%
sns.swarmplot(x=data['Has Bandstructure'],
             y=data['Nsites'])
plt.legend()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 28.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# No handles with labels found to put in legend.

# %%
sns.swarmplot(x=data['Has Bandstructure'],
             y=data['Band Gap (eV)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=data['Has Bandstructure'],
              y=data['E Above Hull (eV)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
#plt.figure(figsize=(20,5))
sns.swarmplot(x=data['Has Bandstructure'],
              y=data['Formation Energy (eV)'])
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(30,5))
sns.lineplot(x=data['Spacegroup'],y=data['E Above Hull (eV)'], label='E Above Hull (eV)')
plt.legend()

# %%
plt.figure(figsize=(30,5))
sns.lineplot(x=data['Spacegroup'], y=data['Band Gap (eV)'], label='Band Gap (eV)')
plt.legend()

# %%
sns.distplot(a=data['Formation Energy (eV)'], kde=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Formation Energy (eV)'>

# %%
sns.kdeplot(data=data['Volume'],shade=True)
# Out:
# <AxesSubplot:xlabel='Volume', ylabel='Density'>

# %%
sns.jointplot(x=data['Volume'],
             y=data['Band Gap (eV)'], kind="kde")

# %%
sns.jointplot(x=data['E Above Hull (eV)'], 
              y=data['Band Gap (eV)'], kind="kde")

# %%
sns.scatterplot(x=data['Nsites'],
               y=data['Volume'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
sns.regplot(x=data['Nsites'], 
                y=data['Volume'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
sns.lmplot(x='Nsites',
          y='Volume',
          hue='Has Bandstructure',
          data=data)

# %%
sns.regplot(x=data['Density (gm/cc)'], 
            y=data['Volume'])
# Out:
# <AxesSubplot:xlabel='Density (gm/cc)', ylabel='Volume'>

# %%
sns.lmplot(x='Density (gm/cc)', 
           y='Volume',
           hue="Has Bandstructure", 
           data=data)

# %%
sns.scatterplot(x=data['Nsites'], 
            y=data['Volume'],
            hue=data['Crystal System'])
# Out:
# <AxesSubplot:xlabel='Nsites', ylabel='Volume'>

# %%
selected = data.loc[:, ['Formation Energy (eV)']]

# %%
data.index.value_counts()
data['Crystal System'].value_counts()
data['Spacegroup'].value_counts()
data['Formula'].value_counts()
# Out:
# LiFeSiO4           42
# LiCoSiO4           29
# Li2FeSiO4          15
# Li2CoSiO4          14
# Li2MnSiO4          12
#                    ..
# Li3Co2Si3O10        1
# Li10Co(SiO5)2       1
# Li4Co2Si3O10        1
# Li2FeSi4O11         1
# Li5Co4(Si3O10)2     1
# Name: Formula, Length: 114, dtype: int64

# %%
sns.heatmap(data=selected, annot=True)
# Out:
# <AxesSubplot:>

# %%
selected.head()
# Out:
#    Formation Energy (eV)
# 0                 -2.699
# 1                 -2.696
# 2                 -2.775
# 3                 -2.783
# 4                 -2.747

# %%
data.head()
# Out:
#   Materials Id       Formula Spacegroup  Formation Energy (eV)  \
# 0    mp-849394     Li2MnSiO4         Pc                 -2.699
# 1    mp-783909     Li2MnSiO4      P21/c                 -2.696
# 2    mp-761311    Li4MnSi2O7         Cc                 -2.775
# 3    mp-761598  Li4Mn2Si3O10       C2/c                 -2.783
# 4    mp-767709  Li2Mn3Si3O10       C2/c                 -2.747
#
#    E Above Hull (eV)  Band Gap (eV)  Nsites  Density (gm/cc)   Volume  \
# 0              0.006          3.462      16            2.993  178.513
# 1              0.008          2.879      32            2.926  365.272
# 2              0.012          3.653      28            2.761  301.775
# 3              0.013          3.015      38            2.908  436.183
# 4              0.016          2.578      36            3.334  421.286
#
#    Has Bandstructure Crystal System
# 0               True     monoclinic
# 1               True     monoclinic
# 2               True     monoclinic
# ...
